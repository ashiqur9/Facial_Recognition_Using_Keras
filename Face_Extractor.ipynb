# %% [markdown]
# <a href="https://colab.research.google.com/github/ashiqur9/Facial_Recognition_Using_Keras/blob/master/Face_Extractor.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# This will will detect faces and crop to 299x299 pixel. This is helpful when you want to dataset for face recognition

# %%
#Import Necessary modules 
import cv2
import time
import matplotlib.pyplot as plt
from glob import iglob
import numpy as np
import os
# %matplotlib inline

# %%
#Load CV2 default cascade Classifier  
face_cascade = cv2.CascadeClassifier('/content/drive/My Drive/Dataset/haarcascade_frontalface_default.xml')

# %%
#Path to save faces
output='/content/drive/My Drive/Dataset/Train/Mark_Ruffalo'
total=0
os.mkdir(output)

# %%
import glob, os
 
for filename in glob.iglob('/content/drive/My Drive/face/Mark_Ruffalo/*', recursive=True):
    print(filename)
    image = cv2.imread(filename)
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    #print(image.shape)
    image_copy = np.copy(image)
    gray_image = cv2.cvtColor(image, cv2.COLOR_RGB2GRAY)
    faces = face_cascade.detectMultiScale(gray_image, 2.0, 6)
    print('Number of faces detected:', len(faces))
    if len(faces)==0:
        faces = face_cascade.detectMultiScale(gray_image, 1.5, 6)
        print('Number of faces detected:', len(faces))
        
    for f in faces:
        x, y, w, h = [ v for v in f ]
        print(y,y+h,x,x+w)
        #cv2.rectangle(image_copy, (x,y), (x+w, y+h), (255,0,0), 3)
        # Define the region of interest in the image  
        face_crop = image_copy[y:y+h, x:x+w]
    
    if len(faces)==1:
      image=face_crop
      r = 299.0 / image.shape[1]
      dim = (299, int(image.shape[0] * r))
      # perform the actual resizing of the image and show it
      resized = cv2.resize(image, dim, interpolation = cv2.INTER_AREA)
      #cv2.imwrite('/home/ashiqur/Desktop/00.png',resized)
      p = os.path.sep.join([output, "{}.png".format(str(total).zfill(5))])
      cv2.imwrite(p, resized) 
      total += 1
      print('success')
      #time.sleep(2)
# Out:
# /content/drive/My Drive/face/Mark_Ruffalo/00000000.jpg?w=1000&h=562&crop=1
# Number of faces detected: 0
# Number of faces detected: 1
# 120 393 345 618
# success
# /content/drive/My Drive/face/Mark_Ruffalo/00000001.jpg
# Number of faces detected: 1
# 491 1259 1162 1930
# success
# /content/drive/My Drive/face/Mark_Ruffalo/00000002.jpg
# Number of faces detected: 0
# Number of faces detected: 1
# 181 454 468 741
# success
# /content/drive/My Drive/face/Mark_Ruffalo/00000003.jpg
# Number of faces detected: 1
# 123 507 224 608
# success
# /content/drive/My Drive/face/Mark_Ruffalo/00000004.jpg
# Number of faces detected: 1
# 325 709 163 547
# success
# /content/drive/My Drive/face/Mark_Ruffalo/00000005.jpg
# Number of faces detected: 0
# Number of faces detected: 1
# 961 3037 2402 4478
# success
# /content/drive/My Drive/face/Mark_Ruffalo/00000006.jpg
# Number of faces detected: 1
# 218 986 128 896
# success
# /content/drive/My Drive/face/Mark_Ruffalo/00000007.jpg
# ...
